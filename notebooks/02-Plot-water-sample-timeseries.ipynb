# %%
# Import modules
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
# Load data from notebook 1 into a Pandas Dataframe
df = pd.read_csv("../data/interim/irminger_sea_subset.csv")
df.head() # Print the first 5 rows of the DataFrame
# Out:
#      Cruise  Target_Asset  Start_Latitude  Start_Longitude  \
# 0  KN221-04  Test Site #1          62.107       -31.381667
# 1  KN221-04  Test Site #1          62.107       -31.381667
# 2  KN221-04  Test Site #1          62.107       -31.381667
# 3  KN221-04  Test Site #1          62.107       -31.381667
# 4  KN221-04  Test Site #1          62.107       -31.381667
#
#                  Start_Time Cast          Cast_Flag   CTD_Bottle_Closure_Time  \
# 0  2014-09-08T11:39:06.000Z    1  *0000000000000100  2014-09-08T12:07:58.000Z
# 1  2014-09-08T11:39:06.000Z    1  *0000000000000100  2014-09-08T12:08:10.000Z
# 2  2014-09-08T11:39:06.000Z    1  *0000000000000100  2014-09-08T12:08:22.000Z
# 3  2014-09-08T11:39:06.000Z    1  *0000000000000100  2014-09-08T12:08:30.000Z
# 4  2014-09-08T11:39:06.000Z    1  *0000000000000100  2014-09-08T12:08:38.000Z
#
#    CTD_Latitude  CTD_Longitude  ...  Discrete_Salinity_Flag  \
# 0      62.10702      -31.38174  ...                     NaN
# 1      62.10702      -31.38176  ...                     NaN
# 2      62.10702      -31.38176  ...                     NaN
# 3      62.10702      -31.38176  ...                     NaN
# 4      62.10702      -31.38174  ...                     NaN
#
#   Discrete_Salinity_Replicate_Flag  CTD_Oxygen    CTD_Oxygen_Flag  \
# 0                              NaN      6.3251  *0000000000000100
# 1                              NaN      6.3326  *0000000000000100
# 2                              NaN      6.3246  *0000000000000100
# 3                              NaN      6.2751  *0000000000000100
# 4                              NaN      6.2838  *0000000000000100
#
#    CTD_Oxygen_Saturation  Discrete_Oxygen  Discrete_Oxygen_Flag  \
# 0                7.30825              NaN                   NaN
# 1                7.30829              NaN                   NaN
# 2                7.30832              NaN                   NaN
# 3                7.30832              NaN                   NaN
# 4                7.30835              NaN                   NaN
#
#   Discrete_Oxygen_Replicate_Flag Discrete_Chlorophyll  Discrete_Phosphate
# 0                            NaN                  NaN                 NaN
# 1                            NaN                  NaN                 NaN
# 2                            NaN                  NaN                 NaN
# 3                            NaN                  NaN                 NaN
# 4                            NaN                  NaN                 NaN
#
# [5 rows x 44 columns]

# %%
# display unique Target_Asset
df.Target_Asset.unique() # display unique one column
# Out:
# array(['Test Site #1', 'Test Site #2', 'Test site #3', 'Test site #4',
#        'GI01SUMO', 'GI02HYPM', 'N102 Mooring', 'Glider test',
#        'release test', 'GI02HYPM-1', 'Gliders', 'GI03FLMA-2',
#        'GI03FLMB-2', 'GI03FLMB-1', 'GI02HYPM-2', 'GI01SUMO-2',
#        'Release test', 'SUMO', 'HYPM', 'FLMA', 'FLMB', 'Release test 1',
#        'Release test 2', 'Release test 3', 'Release test 4',
#        'Release test 5', 'Release test 6', 'SSSG test cast', 'Glider box',
#        'Release Test', 'OSNAP caldip-1', 'OSNAP caldip-2', 'Test Cast',
#        'OSNAP M4', 'OSNAP CV4', 'OSNAP CAB', 'OSNAP M1', 'OSNAP M2',
#        'OSNAP C12', 'OSNAP C01', 'OSNAP M3', 'Gliders 2', 'CL1', 'CL2',
#        'Acoustic Release', 'GI03FLMA', 'GI03FLMB', 'CASISUS',
#        'GI01SUMO, GI02HYPM', 'GI01SUMO, GI02HYPM, Gliders', 'CTD test',
#        'near gliders', 'OSNAP Optode caldip', 'SUMO 7', 'HYPM 6',
#        'SUMO 6 & 7', 'OSNAP M1 / M2', 'FLMB 6 & 7', 'near FLMB-6',
#        'HYMP-7', 'HYPM-7', 'Test cast', 'Acoustic release test',
#        'Glider box/release test', 'M3 - OSNAP', 'M2 - OSNAP',
#        'M1 - OSNAP', 'Transit - CTD test', 'Transit - release test',
#        'Transit - cal dip', 'Transit -  release test', 'Glider',
#        'FLMB - release test', 'M4 - OSNAP', 'OSNAP - cal dip',
#        'OOI - cal dip', 'LADCP test',
#        'Glider deploy; Acoustic release test',
#        'HYPM; Acoustic release test'], dtype=object)

# %%
# Query cast data for a particular target mooring and reset the index
sumo = df[df['Target_Asset'].str.contains("SUMO")]
sumo.reset_index(inplace=True)
sumo.head()
# Out:
#    index    Cruise Target_Asset  Start_Latitude  Start_Longitude  \
# 0     54  KN221-04     GI01SUMO       59.924167       -39.509333
# 1     55  KN221-04     GI01SUMO       59.924167       -39.509333
# 2     56  KN221-04     GI01SUMO       59.924167       -39.509333
# 3     57  KN221-04     GI01SUMO       59.924167       -39.509333
# 4     58  KN221-04     GI01SUMO       59.924167       -39.509333
#
#                  Start_Time Cast          Cast_Flag   CTD_Bottle_Closure_Time  \
# 0  2014-09-11T22:48:32.000Z    5  *0000000000000100  2014-09-11T23:17:06.000Z
# 1  2014-09-11T22:48:32.000Z    5  *0000000000000100  2014-09-11T23:28:19.000Z
# 2  2014-09-11T22:48:32.000Z    5  *0000000000000100  2014-09-11T23:36:09.000Z
# 3  2014-09-11T22:48:32.000Z    5  *0000000000000100  2014-09-11T23:44:03.000Z
# 4  2014-09-11T22:48:32.000Z    5  *0000000000000100  2014-09-11T23:44:22.000Z
#
#    CTD_Latitude  ...  Discrete_Salinity_Flag  \
# 0      59.91976  ...       *0000000000000100
# 1      59.91816  ...       *0000000000000100
# 2      59.91706  ...       *0000000000000100
# 3      59.91578  ...                     NaN
# 4      59.91574  ...       *0000000000000100
#
#    Discrete_Salinity_Replicate_Flag CTD_Oxygen    CTD_Oxygen_Flag  \
# 0                 *0000000000000100     4.6565  *0000000000000100
# 1                 *0000000000000100     5.0284  *0000000000000100
# 2                 *0000000000000100     5.0580  *0000000000000100
# 3                               NaN     4.8944  *0000000000000100
# 4                 *0000000000000100     4.8982  *0000000000000100
#
#    CTD_Oxygen_Saturation  Discrete_Oxygen  Discrete_Oxygen_Flag  \
# 0                7.33166            6.494     *0000000000000100
# 1                7.32346            6.526     *0000000000000100
# 2                7.26561            6.481     *0000000000000100
# 3                7.07312              NaN                   NaN
# 4                7.07281            6.750     *0000000000000100
#
#    Discrete_Oxygen_Replicate_Flag Discrete_Chlorophyll Discrete_Phosphate
# 0               *0000000000000100                  NaN           0.757431
# 1               *0000000000000100                  NaN                NaN
# 2               *0000000000000100                  NaN                NaN
# 3                             NaN                  NaN                NaN
# 4               *0000000000000100                  NaN           0.693823
#
# [5 rows x 45 columns]

# %%
print(sumo.columns)
# Out:
# Index(['index', 'Cruise', 'Target_Asset', 'Start_Latitude', 'Start_Longitude',
#        'Start_Time', 'Cast', 'Cast_Flag', 'CTD_Bottle_Closure_Time',
#        'CTD_Latitude', 'CTD_Longitude', 'CTD_Pressure', 'CTD_Pressure_Flag',
#        'CTD_Depth', 'CTD_pH', 'CTD_pH_Flag', 'Discrete_pH', 'pH_Analysis_Temp',
#        'Discrete_pH_Flag', 'Discrete_pH_Replicate_Flag', 'Calculated_pH',
#        'Discrete_Nitrate', 'Discrete_Nutrients_Flag',
#        'Discrete_Nutrients_Replicate_Flag', 'CTD_Fluorescence',
#        'CTD_Fluorescence_Flag', 'Discrete_Fluorescence_Flag',
#        'Discrete_Fluorescence_Replicate_Flag', 'CTD_Temperature_1',
#        'CTD_Temperature_1_Flag', 'CTD_Temperature_2', 'CTD_Temperature_2_Flag',
#        'CTD_Salinity_1', 'CTD_Salinity_2', 'Discrete_Salinity',
#        'Discrete_Salinity_Flag', 'Discrete_Salinity_Replicate_Flag',
#        'CTD_Oxygen', 'CTD_Oxygen_Flag', 'CTD_Oxygen_Saturation',
#        'Discrete_Oxygen', 'Discrete_Oxygen_Flag',
#        'Discrete_Oxygen_Replicate_Flag', 'Discrete_Chlorophyll',
#        'Discrete_Phosphate'],
#       dtype='object')

# %%
some_vars = sumo[["CTD_Depth", "Discrete_Oxygen", "Discrete_Nitrate"]]

# %%
some_vars
# Out:
#      CTD_Depth  Discrete_Oxygen  Discrete_Nitrate
# 0     1483.447            6.494         11.296021
# 1      888.824            6.526               NaN
# 2      493.864            6.481               NaN
# 3      102.087              NaN               NaN
# 4      102.230            6.750          7.709425
# ..         ...              ...               ...
# 287     44.388            6.434          7.348000
# 288     24.282            6.499               NaN
# 289     16.365            6.524          6.185000
# 290     16.365              NaN          5.418000
# 291      3.618            6.586          7.692000
#
# [292 rows x 3 columns]

# %%
cast_cmap = mpl.colormaps['Accent'].reversed() # Reversed in attempt to improve colorblind-friendliness

# %%
time = pd.to_datetime(sumo["CTD_Bottle_Closure_Time"], yearfirst=True, utc=True).values

# %%
# Create the subplots
fig, axs = plt.subplots(2, 1, sharex=True, layout="tight")
# Discrete Oxygen
plt.subplot(2,1,1)
plt.scatter(x=time, y=sumo["Discrete_Oxygen"], c=sumo["Cast"].astype(float), cmap=cast_cmap, edgecolors="none")
plt.grid()
axs[0].set_ylabel("Discrete Oxygen")

# Discrete Nitrate
plt.subplot(2,1,2)
plt.scatter(x=time, y=sumo["Discrete_Nitrate"], c=sumo["Cast"].astype(float), cmap=cast_cmap, edgecolors="none")
plt.grid()
axs[1].set_ylabel("Discrete Nitrate")
axs[1].set_xlabel("Time")
# Out:
# Text(0.5, 0, 'Time')
